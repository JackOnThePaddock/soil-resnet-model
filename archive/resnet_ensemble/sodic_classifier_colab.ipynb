# %% [markdown]
# # Sodicity Classifier (ESP > 6%)
# This notebook trains a **binary classifier** to detect sodic soils using AlphaEarth embeddings.
#
# ## Files Needed
# Upload one or more of these files:
# - `soil_data_2017_alphaearth.csv` ... `soil_data_2024_alphaearth.csv` (raw ESP + band_0..band_63)
#
# They must contain `esp` and `band_0..band_63`.

# %%
# !pip -q install xgboost scikit-learn pandas numpy

# %%
# Option A: Run after uploading files to Colab
# !python sodic_classifier_colab.py --data-dir . --pattern "soil_data_*_alphaearth.csv" --threshold 6

# %%
# Option B: Run from Google Drive (edit paths)
from google.colab import drive
drive.mount('/content/drive')

data_dir = '/content/drive/MyDrive/soil/alphaearth_raw'
# !python sodic_classifier_colab.py --data-dir "{data_dir}" --pattern "soil_data_*_alphaearth.csv" --threshold 6
