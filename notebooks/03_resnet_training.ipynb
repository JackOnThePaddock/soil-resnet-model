# %% [markdown]
# # ResNet Soil Prediction (Colab)
# This notebook runs the `resnet_colab.py` script against the normalized training CSV.
#
# ## Option A: Upload files
# Use the Colab sidebar to upload:
# - `resnet_colab.py`
# - `soil_data_alphaearth_normalized.csv`
#
# Then run the next cell.
#
# ## Option B: Google Drive
# If your files are in Drive, update the paths in the Drive cell below.

# %%
# Install dependencies
# !pip -q install torch scikit-learn pandas numpy

# %%
# Option A: Run after uploading files to Colab
# !python resnet_colab.py --data "soil_data_alphaearth_normalized.csv" --ensemble_size 5
# Out:
# Loaded 3534 samples with 7 targets
#   ph: 3511 valid values
#   cec: 694 valid values
#   esp: 563 valid values
#   soc: 755 valid values
#   ca: 1823 valid values
#   mg: 1775 valid values
#   na: 1309 valid values
# Using device: cuda
#
# ==================================================
# Training Model 1/5
# ==================================================
#
#   Fold 1/5
#     Epoch 50: val_loss=0.4728
#     Early stopping at epoch 52
#
#   Fold 2/5
#     Epoch 50: val_loss=0.5046
#     Epoch 100: val_loss=0.4849
#     Early stopping at epoch 113
#
#   Fold 3/5
#     Epoch 50: val_loss=0.3384
#     Epoch 100: val_loss=0.3146
#     Epoch 150: val_loss=0.3142
#     Early stopping at epoch 168
#
#   Fold 4/5
#     Epoch 50: val_loss=0.3968
#     Epoch 100: val_loss=0.3871
#     Epoch 150: val_loss=0.3840
#     Early stopping at epoch 173
#
#   Fold 5/5
#     Epoch 50: val_loss=0.4467
#     Epoch 100: val_loss=0.4396
#     Early stopping at epoch 129
#
#   Training final model 1 on all data...
#
#   Model 1 CV Results:
#     ph: R2=0.643
#     cec: R2=0.693
#     esp: R2=0.138
#     soc: R2=0.583
#     ca: R2=0.574
#     mg: R2=0.524
#     na: R2=0.080
#
# ==================================================
# Training Model 2/5
# ==================================================
#
#   Fold 1/5
#     Epoch 50: val_loss=0.4475
#     Early stopping at epoch 63
#
#   Fold 2/5
#     Epoch 50: val_loss=0.5048
#     Epoch 100: val_loss=0.4918
#     Epoch 150: val_loss=0.4719
#     Early stopping at epoch 163
#
#   Fold 3/5
#     Epoch 50: val_loss=0.3206
#     Epoch 100: val_loss=0.3189
#     Early stopping at epoch 114
#
#   Fold 4/5
#     Epoch 50: val_loss=0.3836
#     Early stopping at epoch 85
#
#   Fold 5/5
#     Epoch 50: val_loss=0.4271
#     Epoch 100: val_loss=0.4140
#     Early stopping at epoch 134
#
#   Training final model 2 on all data...
#
#   Model 2 CV Results:
#     ph: R2=0.648
#     cec: R2=0.715
#     esp: R2=0.188
#     soc: R2=0.612
#     ca: R2=0.577
#     mg: R2=0.550
#     na: R2=0.195
#
# ==================================================
# Training Model 3/5
# ==================================================
#
#   Fold 1/5
#     Epoch 50: val_loss=0.4655
#     Early stopping at epoch 51
#
#   Fold 2/5
#     Epoch 50: val_loss=0.5152
#     Epoch 100: val_loss=0.5044
#     Early stopping at epoch 106
#
#   Fold 3/5
#     Epoch 50: val_loss=0.3356
#     Epoch 100: val_loss=0.3288
#     Early stopping at epoch 127
#
#   Fold 4/5
#     Epoch 50: val_loss=0.4136
#     Early stopping at epoch 87
#
#   Fold 5/5
#     Epoch 50: val_loss=0.4505
#     Epoch 100: val_loss=0.4186
#     Early stopping at epoch 124
#
#   Training final model 3 on all data...
#
#   Model 3 CV Results:
#     ph: R2=0.644
#     cec: R2=0.700
#     esp: R2=0.184
#     soc: R2=0.601
#     ca: R2=0.553
#     mg: R2=0.525
#     na: R2=0.097
#
# ==================================================
# Training Model 4/5
# ==================================================
#
#   Fold 1/5
#     Epoch 50: val_loss=0.4703
#     Early stopping at epoch 50
#
#   Fold 2/5
#     Epoch 50: val_loss=0.5244
#     Epoch 100: val_loss=0.4987
#     Early stopping at epoch 120
#
#   Fold 3/5
#     Epoch 50: val_loss=0.3391
#     Early stopping at epoch 84
#
#   Fold 4/5
#     Epoch 50: val_loss=0.3949
#     Epoch 100: val_loss=0.3850
#     Early stopping at epoch 109
#
#   Fold 5/5
#     Epoch 50: val_loss=0.4526
#     Epoch 100: val_loss=0.4343
#     Early stopping at epoch 117
#
#   Training final model 4 on all data...
#
#   Model 4 CV Results:
#     ph: R2=0.643
#     cec: R2=0.685
#     esp: R2=0.171
#     soc: R2=0.600
#     ca: R2=0.538
#     mg: R2=0.501
#     na: R2=0.084
#
# ==================================================
# Training Model 5/5
# ==================================================
#
#   Fold 1/5
#     Epoch 50: val_loss=0.4710
#     Early stopping at epoch 52
#
#   Fold 2/5
#     Epoch 50: val_loss=0.5111
#     Epoch 100: val_loss=0.5059
#     Early stopping at epoch 102
#
#   Fold 3/5
#     Epoch 50: val_loss=0.3237
#     Epoch 100: val_loss=0.3176
#     Early stopping at epoch 134
#
#   Fold 4/5
#     Epoch 50: val_loss=0.4006
#     Epoch 100: val_loss=0.3935
#     Early stopping at epoch 139
#
#   Fold 5/5
#     Epoch 50: val_loss=0.4389
#     Epoch 100: val_loss=0.4255
#     Early stopping at epoch 135
#
#   Training final model 5 on all data...
#
#   Model 5 CV Results:
#     ph: R2=0.647
#     cec: R2=0.682
#     esp: R2=0.174
#     soc: R2=0.626
#     ca: R2=0.554
#     mg: R2=0.488
#     na: R2=0.099
#
# ==================================================
# ENSEMBLE TRAINING COMPLETE
# ==================================================
#
# Average R2 across all models:
#   ph: 0.645 (+/- 0.002)
#   cec: 0.695 (+/- 0.012)
#   esp: 0.171 (+/- 0.018)
#   soc: 0.605 (+/- 0.014)
#   ca: 0.559 (+/- 0.015)
#   mg: 0.518 (+/- 0.021)
#   na: 0.111 (+/- 0.043)
#
# Models saved to: resnet_output/models

# %%
# Option B: Run from Google Drive (edit paths)
from google.colab import drive
drive.mount('/content/drive')

# Update these paths if your files are in a different folder
script_path = '/content/drive/MyDrive/soil/resnet_colab.py'
data_path = '/content/drive/MyDrive/soil/soil_data_alphaearth_normalized.csv'

# !python "{script_path}" --data "{data_path}" --ensemble_size 5
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-2561178850.py in <cell line: 0>()
#       1 # Option B: Run from Google Drive (edit paths)
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#       4
#       5 # Update these paths if your files are in a different folder
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# Outputs will be saved under `./resnet_output/models/` in the Colab session.
